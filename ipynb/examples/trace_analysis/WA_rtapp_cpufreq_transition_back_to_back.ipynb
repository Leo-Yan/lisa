# %% [markdown]
# # Workload rtapp + Idle States Residency Analysis

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()

# Execute this cell to enabled devlib debugging statements
logging.getLogger('ssh').setLevel(logging.DEBUG)
# Out:
# 2018-12-12 17:20:51,317 INFO    : root         : Using LISA logging configuration:
# 2018-12-12 17:20:51,319 INFO    : root         :   /home/leoy/Work2/Develop/tools/lisa/logging.conf

# %%
# %matplotlib inline

import os

# Support to access the remote target
from env import TestEnv

# Support to access cpuidle information from the target
from devlib import *

# Support to configure and run RTApp based workloads
from wlgen import RTA, Ramp, Periodic

# Support for trace events analysis
from trace import Trace
from trace import ResidencyTime, ResidencyData

# DataFrame support
import pandas as pd
from pandas import DataFrame

# Trappy (plots) support
from trappy import ILinePlot
from trappy.stats.grammar import Parser

import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt

import json

# %% [markdown]
# # Hikey960 Platform Configurations

# %%
# Setup target configuration
hikey960_conf = {
    "platform"     : 'linux',
    "board"        : 'hikey',
    "host"         : "192.168.2.24",
    "username"     : "root",
    "password"     : "root",
    "results_dir"  : "cpuidle_post_opt",
    "modules"      : [ 'cpufreq', 'cpuidle' ],
    "ftrace"       : {
        "events" : [ 
            "cpu_idle",
            "cpu_capacity",
            "cpu_frequency",
            "sched_switch",
            "sched_load_avg_cpu",
            "cpuidle_interval_stats",
            "cpuidle_state_idx",
            "cpuidle_factor",
            "irq_handler_entry",
            "ipi_entry_rcuidle",
            "softirq_raise",
            "sched_migrate_task",
            "sched_switch",
            "sched_wakeup",
            "sched_wakeup_new",
            "sched_contrib_scale_f",
            "sched_load_avg_cpu",
            "sched_load_avg_task"            
        ],
        "buffsize" : 50 * 1024,
    },
    "tools"        : [ 'trace-cmd', 'taskset', 'rt-app', 'sysbench' ],
    "rtapp-calib"  : {
        "0": 301, "1": 301, "2": 301, "3": 301, "4": 155, "5": 155, "6": 155, "7": 155,
    },  
}

# %% [markdown]
# # Connect with target board

# %%
# Support to access the remote target
from env import TestEnv

te = TestEnv(hikey960_conf)
target = te.target
# Out:
# 2018-12-12 17:20:54,356 INFO    : TestEnv      : Using base path: /home/leoy/Work2/Develop/tools/lisa
# 2018-12-12 17:20:54,358 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2018-12-12 17:20:54,360 WARNING : TestEnv      : Wipe previous contents of the results folder:
# 2018-12-12 17:20:54,361 WARNING : TestEnv      :    /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt
# 2018-12-12 17:20:54,365 INFO    : TestEnv      : Devlib modules to load: ['cpuidle', 'cpufreq']
# 2018-12-12 17:20:54,366 INFO    : TestEnv      : Connecting linux target:
# 2018-12-12 17:20:54,368 INFO    : TestEnv      :   username : root
# 2018-12-12 17:20:54,369 INFO    : TestEnv      :       host : 192.168.2.24
# 2018-12-12 17:20:54,370 INFO    : TestEnv      :   password : root
# 2018-12-12 17:20:54,372 INFO    : TestEnv      : Connection settings:
# 2018-12-12 17:20:54,373 INFO    : TestEnv      :    {'username': 'root', 'host': '192.168.2.24', 'password': 'root'}
# 2018-12-12 17:20:54,383 DEBUG   : ssh          : Logging in root@192.168.2.24
# 2018-12-12 17:20:55,592 DEBUG   : ssh          : (id); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:55,763 DEBUG   : ssh          : (mkdir -p /root/devlib-target); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:55,931 DEBUG   : ssh          : (mkdir -p /root/devlib-target/bin); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:56,099 DEBUG   : ssh          : (uname -m); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:56,167 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/libs/devlib/devlib/bin/arm64/busybox "root"@"192.168.2.24":"/root/devlib-target/bin/busybox"
# 2018-12-12 17:20:56,696 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/busybox); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:56,866 DEBUG   : ssh          : (cat /proc/cpuinfo); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:57,035 DEBUG   : ssh          : (if [ -e '/sys/devices/system/cpu/cpuidle' ]; then echo 1; else echo 0; fi); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:57,105 DEBUG   : ssh          : /usr/bin/scp -r   /tmp/tmpmFpIWQ/shutils "root"@"192.168.2.24":"/root/devlib-target/bin/shutils"
# 2018-12-12 17:20:57,452 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/shutils); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:57,622 DEBUG   : ssh          : (/root/devlib-target/bin/shutils read_tree_values /sys/devices/system/cpu/ 4); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:57,997 DEBUG   : ssh          : (if [ -e '/sys/devices/system/cpu/cpufreq' ]; then echo 1; else echo 0; fi); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:58,063 INFO    : TestEnv      : Initializing target workdir:
# 2018-12-12 17:20:58,065 INFO    : TestEnv      :    /root/devlib-target
# 2018-12-12 17:20:58,067 DEBUG   : ssh          : /usr/bin/scp -r   /tmp/tmpfBa2h9/shutils "root"@"192.168.2.24":"/root/devlib-target/bin/shutils"
# 2018-12-12 17:20:58,445 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/shutils); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:58,609 DEBUG   : ssh          : (mkdir -p /root/devlib-target/.file-cache); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:58,678 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/arm64/perf "root"@"192.168.2.24":"/root/devlib-target/bin/perf"
# 2018-12-12 17:20:59,121 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/perf); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:59,190 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/arm64/rt-app "root"@"192.168.2.24":"/root/devlib-target/bin/rt-app"
# 2018-12-12 17:20:59,644 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/rt-app); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:20:59,716 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/scripts/cgroup_run_into.sh "root"@"192.168.2.24":"/root/devlib-target/bin/cgroup_run_into.sh"
# 2018-12-12 17:21:00,085 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/cgroup_run_into.sh); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:00,156 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/arm64/trace-cmd "root"@"192.168.2.24":"/root/devlib-target/bin/trace-cmd"
# 2018-12-12 17:21:00,982 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/trace-cmd); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:01,049 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/arm64/taskset "root"@"192.168.2.24":"/root/devlib-target/bin/taskset"
# 2018-12-12 17:21:01,767 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/taskset); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:01,834 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/tools/arm64/sysbench "root"@"192.168.2.24":"/root/devlib-target/bin/sysbench"
# 2018-12-12 17:21:02,258 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/sysbench); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:02,321 INFO    : TestEnv      : Topology:
# 2018-12-12 17:21:02,323 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2018-12-12 17:21:02,425 DEBUG   : ssh          : (cat /sys/devices/system/cpu/cpu0/cpufreq/scaling_available_frequencies); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:02,593 DEBUG   : ssh          : (cat /sys/devices/system/cpu/cpu4/cpufreq/scaling_available_frequencies); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:02,657 INFO    : TestEnv      : Loading default EM:
# 2018-12-12 17:21:02,659 INFO    : TestEnv      :    /home/leoy/Work2/Develop/tools/lisa/libs/utils/platforms/hikey.json
# 2018-12-12 17:21:02,762 DEBUG   : ssh          : (/root/devlib-target/bin/busybox uname -r -v); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:02,839 DEBUG   : ssh          : /usr/bin/scp -r   /home/leoy/Work2/Develop/tools/lisa/libs/devlib/devlib/bin/arm64/trace-cmd "root"@"192.168.2.24":"/root/devlib-target/bin/trace-cmd"
# 2018-12-12 17:21:03,321 DEBUG   : ssh          : (chmod a+x /root/devlib-target/bin/trace-cmd); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:03,488 DEBUG   : ssh          : (cat /sys/kernel/debug/tracing/available_events); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:03,563 WARNING : LinuxTarget  : Event [cpu_capacity] not available for tracing
# 2018-12-12 17:21:03,567 WARNING : LinuxTarget  : Event [cpuidle_factor] not available for tracing
# 2018-12-12 17:21:03,569 WARNING : LinuxTarget  : Event [cpuidle_interval_stats] not available for tracing
# 2018-12-12 17:21:03,571 WARNING : LinuxTarget  : Event [cpuidle_state_idx] not available for tracing
# 2018-12-12 17:21:03,572 WARNING : LinuxTarget  : Event [ipi_entry_rcuidle] not available for tracing
# 2018-12-12 17:21:03,575 WARNING : LinuxTarget  : Event [sched_contrib_scale_f] not available for tracing
# 2018-12-12 17:21:03,576 WARNING : LinuxTarget  : Event [sched_load_avg_cpu] not available for tracing
# 2018-12-12 17:21:03,578 WARNING : LinuxTarget  : Event [sched_load_avg_task] not available for tracing
# 2018-12-12 17:21:03,581 INFO    : TestEnv      : Enabled tracepoints:
# 2018-12-12 17:21:03,583 INFO    : TestEnv      :    cpu_capacity
# 2018-12-12 17:21:03,584 INFO    : TestEnv      :    cpu_frequency
# 2018-12-12 17:21:03,585 INFO    : TestEnv      :    cpu_idle
# 2018-12-12 17:21:03,587 INFO    : TestEnv      :    cpuidle_factor
# 2018-12-12 17:21:03,588 INFO    : TestEnv      :    cpuidle_interval_stats
# 2018-12-12 17:21:03,592 INFO    : TestEnv      :    cpuidle_state_idx
# 2018-12-12 17:21:03,593 INFO    : TestEnv      :    ipi_entry_rcuidle
# 2018-12-12 17:21:03,595 INFO    : TestEnv      :    irq_handler_entry
# 2018-12-12 17:21:03,597 INFO    : TestEnv      :    sched_contrib_scale_f
# 2018-12-12 17:21:03,599 INFO    : TestEnv      :    sched_load_avg_cpu
# 2018-12-12 17:21:03,601 INFO    : TestEnv      :    sched_load_avg_task
# 2018-12-12 17:21:03,602 INFO    : TestEnv      :    sched_migrate_task
# 2018-12-12 17:21:03,604 INFO    : TestEnv      :    sched_switch
# 2018-12-12 17:21:03,605 INFO    : TestEnv      :    sched_wakeup
# 2018-12-12 17:21:03,606 INFO    : TestEnv      :    sched_wakeup_new
# 2018-12-12 17:21:03,608 INFO    : TestEnv      :    softirq_raise
# 2018-12-12 17:21:03,609 INFO    : TestEnv      : Using configuration provided RTApp calibration
# 2018-12-12 17:21:03,611 INFO    : TestEnv      : Using RT-App calibration values:
# 2018-12-12 17:21:03,612 INFO    : TestEnv      :    {"0": 301, "1": 301, "2": 301, "3": 301, "4": 155, "5": 155, "6": 155, "7": 155}
# 2018-12-12 17:21:03,613 INFO    : TestEnv      : Set results folder to:
# 2018-12-12 17:21:03,615 INFO    : TestEnv      :    /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt
# 2018-12-12 17:21:03,616 INFO    : TestEnv      : Experiment results available also in:
# 2018-12-12 17:21:03,617 INFO    : TestEnv      :    /home/leoy/Work2/Develop/tools/lisa/results_latest

# %%
target.cpufreq.set_all_governors('schedutil')
target.cpufreq.set_governor_tunables(
        0, 'schedutil',
        **{'rate_limit_us' : 100 }
    )
# Out:
# 2018-12-12 17:21:03,729 DEBUG   : ssh          : (/root/devlib-target/bin/shutils cpufreq_set_all_governors schedutil); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:03,897 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu0/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,064 DEBUG   : ssh          : (ls -1 /sys/devices/system/cpu/cpu0/cpufreq/schedutil); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,228 DEBUG   : ssh          : (ls -1 /sys/devices/system/cpu/cpufreq/schedutil); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,396 DEBUG   : ssh          : (echo 100 > '/sys/devices/system/cpu/cpu0/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,562 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu0/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,725 DEBUG   : ssh          : (if [ -e '/sys/devices/system/cpu/cpu0/cpufreq/schedutil/rate_limit_us' ]; then echo 1; else echo 0; fi); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:04,890 DEBUG   : ssh          : (echo 100 > '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:05,058 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec

# %%
littles_tunables = target.cpufreq.get_governor_tunables(0)
littles_tunables
# Out:
# 2018-12-12 17:21:05,234 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu0/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:05,398 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu0/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:05,563 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu0/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:05,728 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# {'rate_limit_us': '100'}

# %%
target.cpufreq.set_governor_tunables(
        4, 'schedutil',
        **{'rate_limit_us' : 100 }
    )
# Out:
# 2018-12-12 17:21:05,915 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu4/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:06,083 DEBUG   : ssh          : (echo 100 > '/sys/devices/system/cpu/cpu4/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:06,250 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu4/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:06,418 DEBUG   : ssh          : (if [ -e '/sys/devices/system/cpu/cpu4/cpufreq/schedutil/rate_limit_us' ]; then echo 1; else echo 0; fi); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:06,584 DEBUG   : ssh          : (echo 100 > '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:06,750 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec

# %%
bigs_tunables = target.cpufreq.get_governor_tunables(4)
bigs_tunables
# Out:
# 2018-12-12 17:21:06,934 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu4/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:07,102 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu4/cpufreq/scaling_governor'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:07,269 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpu4/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:21:07,434 DEBUG   : ssh          : (cat '/sys/devices/system/cpu/cpufreq/schedutil/rate_limit_us'); __devlib_ec=$?; echo; echo $__devlib_ec
# {'rate_limit_us': '100'}

# %% [markdown]
# # Workload execution utility

# %%
def execute(te, wload, res_dir):
    
    logging.info('# Create results folder for this execution')
    # !mkdir {res_dir}
    
    logging.info('# Setup FTrace')
    te.ftrace.start()

    #logging.info('## Start energy sampling')
    #te.emeter.reset()

    logging.info('### Start RTApp execution')
    wload.run(out_dir=res_dir)

    #logging.info('## Read energy consumption: %s/energy.json', res_dir)
    #nrg_report = te.emeter.report(out_dir=res_dir)

    logging.info('# Stop FTrace')
    te.ftrace.stop()

    trace_file = os.path.join(res_dir, 'trace.dat')
    logging.info('# Save FTrace: %s', trace_file)
    te.ftrace.get_trace(trace_file)

    logging.info('# Save platform description: %s/platform.json', res_dir)
    plt, plt_file = te.platform_dump(res_dir)
    
    logging.info('# Report collected data:')
    logging.info('   %s', res_dir)
    # !ls -la {res_dir}
    
    return plt, plt_file, trace_file

# %% [markdown]
# # Workload Definition : Single task (period: 10ms, dc: 10%)

# %%
rtapp_name = 'example_10ms_10pct'
rtapp = RTA(target, rtapp_name, calibration=te.calibration())

# Configure this RTApp instance to:
rtapp.conf(

    # 1. generate a "profile based" set of tasks
    kind = 'profile',
    
    # 2. define the "profile" of each task
    params = {
        
        # 3. PERIODIC task with
        'task_p20': Periodic (
            period_ms      = 10, # period [ms]
            duty_cycle_pct = 30,  # duty cycle [%]
            duration_s     = 30, # duration [s]
            delay_s        = 0,  # start after that delay [s]
            sched          = {   # run as a low-priority SCHED_OTHER task
                'policy'   : 'OTHER',
                #'priotity' : 120,
            },
            cpus           = "4"
        ).get(),

    },
);
# Out:
# 2018-12-12 17:23:28,159 INFO    : Workload     : Setup new workload example_10ms_10pct
# 2018-12-12 17:23:28,261 DEBUG   : ssh          : (mkdir -p /root/devlib-target); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:28,329 INFO    : Workload     : Workload duration defined by longest task
# 2018-12-12 17:23:28,331 INFO    : Workload     : Default policy: SCHED_OTHER
# 2018-12-12 17:23:28,332 INFO    : Workload     : ------------------------
# 2018-12-12 17:23:28,335 INFO    : Workload     : task [task_p20], sched: {'policy': 'OTHER'}
# 2018-12-12 17:23:28,336 INFO    : Workload     :  | loops count: 1
# 2018-12-12 17:23:28,338 INFO    : Workload     : + phase_000001: duration 30.000000 [s] (3000 loops)
# 2018-12-12 17:23:28,341 INFO    : Workload     : |  period    10000 [us], duty_cycle  30 %
# 2018-12-12 17:23:28,343 INFO    : Workload     : |  run_time   3000 [us], sleep_time   7000 [us]
# 2018-12-12 17:23:28,345 INFO    : Workload     : |  CPUs affinity: 4
# 2018-12-12 17:23:28,346 DEBUG   : ssh          : /usr/bin/scp -r   example_10ms_10pct_00.json "root"@"192.168.2.24":"/root/devlib-target"

# %% [markdown]
# # Run the test case and generate trace data

# %%
res_dir = os.path.join(te.res_dir, rtapp_name)
plt, plt_file, trace_file = execute(te, rtapp, res_dir)
# Out:
# 2018-12-12 17:23:28,887 INFO    : root         : # Create results folder for this execution
# mkdir: cannot create directory ‘/home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct’: File exists
# 2018-12-12 17:23:29,001 INFO    : root         : # Setup FTrace
# 2018-12-12 17:23:29,103 DEBUG   : ssh          : (echo 51200 > '/sys/kernel/debug/tracing/buffer_size_kb'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:29,288 DEBUG   : ssh          : (cat '/sys/kernel/debug/tracing/buffer_size_kb'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:29,455 DEBUG   : ssh          : (/root/devlib-target/bin/trace-cmd reset); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:31,016 DEBUG   : ssh          : (/root/devlib-target/bin/trace-cmd start -e cpu_frequency -e cpu_idle -e irq_handler_entry -e sched_migrate_task -e sched_switch -e sched_wakeup -e sched_wakeup_new -e softirq_raise); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:32,594 DEBUG   : ssh          : (echo TRACE_MARKER_START > '/sys/kernel/debug/tracing/trace_marker'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:32,761 DEBUG   : ssh          : (/root/devlib-target/bin/shutils cpufreq_trace_all_frequencies); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:32,928 DEBUG   : ssh          : (/root/devlib-target/bin/shutils cpuidle_wake_all_cpus); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:23:33,007 INFO    : root         : ### Start RTApp execution
# 2018-12-12 17:23:33,009 INFO    : Workload     : Workload execution START:
# 2018-12-12 17:23:33,010 INFO    : Workload     :    /root/devlib-target/bin/rt-app /root/devlib-target/example_10ms_10pct_00.json 2>&1
# 2018-12-12 17:23:33,113 DEBUG   : ssh          : (/root/devlib-target/bin/rt-app /root/devlib-target/example_10ms_10pct_00.json 2>&1); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:24:03,179 DEBUG   : ssh          : /usr/bin/scp -r   "root"@"192.168.2.24":"/root/devlib-target/*task_p20*.log" /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct
# 2018-12-12 17:24:03,485 DEBUG   : ssh          : /usr/bin/scp -r   "root"@"192.168.2.24":"/root/devlib-target/example_10ms_10pct_00.json" /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct
# 2018-12-12 17:24:03,787 INFO    : root         : # Stop FTrace
# 2018-12-12 17:24:03,890 DEBUG   : ssh          : (/root/devlib-target/bin/shutils cpufreq_trace_all_frequencies); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:24:04,063 DEBUG   : ssh          : (echo TRACE_MARKER_STOP > '/sys/kernel/debug/tracing/trace_marker'); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:24:04,230 DEBUG   : ssh          : (/root/devlib-target/bin/trace-cmd stop); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:24:04,297 INFO    : root         : # Save FTrace: /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct/trace.dat
# 2018-12-12 17:24:04,400 DEBUG   : ssh          : (/root/devlib-target/bin/trace-cmd extract -o /root/devlib-target/trace.dat; chmod 666 /root/devlib-target/trace.dat); __devlib_ec=$?; echo; echo $__devlib_ec
# 2018-12-12 17:24:06,195 DEBUG   : ssh          : /usr/bin/scp -r   "root"@"192.168.2.24":"/root/devlib-target/trace.dat" /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct/trace.dat
# 2018-12-12 17:24:07,151 INFO    : root         : # Save platform description: /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct/platform.json
# 2018-12-12 17:24:07,157 INFO    : root         : # Report collected data:
# 2018-12-12 17:24:07,160 INFO    : root         :    /home/leoy/Work2/Develop/tools/lisa/results/cpuidle_post_opt/example_10ms_10pct
# total 8124
# drwxrwxr-x 3 leoy leoy    4096 Dec 12 17:21 .
# drwxrwxr-x 3 leoy leoy    4096 Dec 12 17:21 ..
# -rw-r--r-- 1 leoy leoy     639 Dec 12 17:24 example_10ms_10pct_00.json
# -rw-rw-r-- 1 leoy leoy     175 Dec 12 17:24 output.log
# -rw-rw-r-- 1 leoy leoy    1514 Dec 12 17:24 platform.json
# -rw-r--r-- 1 leoy leoy  372160 Dec 12 17:24 rt-app-task_p20-0.log
# -rw-rw-r-- 1 leoy leoy 7921664 Dec 12 17:24 trace.dat
# drwxrwxr-x 2 leoy leoy    4096 Dec 12 17:21 .trace.dat.cache

# %% [markdown]
# # Load Ftrace Data

# %%
# Time range from the analysis
(t_min, t_max) = (0, None)
    
trace = Trace(plt, trace_file, events=hikey960_conf['ftrace']['events'], window=(t_min,t_max))
# Out:
# /home/leoy/Work2/Develop/tools/lisa/libs/trappy/trappy/ftrace.py:201: UserWarning: Cached data is from another trace, invalidating cache.
#   warnings.warn(warnstr)
# 2018-12-12 17:24:09,953 INFO    : Trace        : Platform clusters verified to be Frequency coherent

# %% [markdown]
# # Display the trace event

# %%
# Original TRAPpy::FTrace DataSet are still accessible by specifying the
# trace event name of interest
trace.data_frame.trace_event('sched_switch').head()
# Out:
#                  __comm  __cpu  __line  __pid    next_comm  next_pid  \
# Time
# 0.000046      trace-cmd      5       2   3580    swapper/5         0
# 0.000307         <idle>      6       5      0         bash      3346
# 0.000803           bash      6      17   3346  kworker/6:3      3124
# 0.000857  kworker/dying      6      18   3124  kworker/6:0      2950
# 0.000887    kworker/6:0      6      19   2950         bash      3346
#
#           next_prio      prev_comm  prev_pid  prev_prio  prev_state
# Time
# 0.000046        120      trace-cmd      3580        120          32
# 0.000307        120      swapper/6         0        120           0
# 0.000803        120           bash      3346        120         256
# 0.000857        120  kworker/dying      3124        120          16
# 0.000887        120    kworker/6:0      2950        120         128

# %%
trace.data_frame.trace_event('cpu_frequency')['frequency'] = trace.data_frame.trace_event('cpu_frequency')['frequency']/1000

# %%
trace.data_frame.trace_event('cpu_frequency')['__cpu']
# Out:
# Time
# 0.164377     3
# 0.164380     3
# 0.164382     3
# 0.164384     3
# 0.168958     3
# 0.168959     3
# 0.168959     3
# 0.168961     3
# 0.331105     4
# 0.331106     4
# 0.331106     4
# 0.331107     4
# 0.334145     3
# 0.334148     3
# 0.334150     3
# 0.334152     3
# 0.337297     3
# 0.337298     3
# 0.337299     3
# 0.337299     3
# 0.345224     4
# 0.345225     4
# 0.345226     4
# 0.345226     4
# 0.349835     4
# 0.349835     4
# 0.349836     4
# 0.349836     4
# 0.498024     3
# 0.498027     3
#             ..
# 31.464993    3
# 31.464993    3
# 31.467591    3
# 31.467593    3
# 31.467595    3
# 31.467597    3
# 31.468666    3
# 31.468667    3
# 31.468668    3
# 31.468668    3
# 31.470671    6
# 31.470702    6
# 31.470731    6
# 31.470761    6
# 31.633464    3
# 31.633466    3
# 31.633468    3
# 31.633470    3
# 31.636861    3
# 31.636862    3
# 31.636863    3
# 31.636864    3
# 31.800404    3
# 31.800406    3
# 31.800409    3
# 31.800411    3
# 31.805206    3
# 31.805207    3
# 31.805208    3
# 31.805209    3
# Name: __cpu, Length: 3364, dtype: int64

# %% [markdown]
# # Plot CPU Frequency

# %%
import trappy

ftrace = trace.ftrace

# These two paramatere are passed to the LinePlot call as long with the
# TRAPpy FTrace object
trappy.ILinePlot(
    
    # FTrace object
    ftrace,
    
    # Signals to be plotted
    signals= [
        'cpu_frequency:frequency',
        'sched_switch:next_pid'
    ],
    
    # Generate one plot for each value of the specified column
    #pivot='__cpu',
    
    # Generate only plots which satisfy these filters
    filters = {
        # Column
        # |     Values
        # |     |
        '__cpu' : [4, 5, 6, 7]
    },
    
    # Formatting style
    drawstyle='steps-post',
    marker = '+'

).view()
# Out:
# <table style="border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_d3e1e5bc38ae40e8815664a953f1fe54"></div></td>
# </tr>
# <tr>
# <td style="border-style: hidden;"><div style="text-align:center" id="fig_d3e1e5bc38ae40e8815664a953f1fe54_legend"></div></td>
# </tr>
# </table>
# <script>
# var fig_d3e1e5bc38ae40e8815664a953f1fe54_data = {"logscale": false, "strokeWidth": 1.0, "pointSize": 2, "name": "fig_d3e1e5bc38ae40e8815664a953f1fe54", "step_plot": true, "fill_graph": false, "title": "", "drawPoints": false, "per_line": 1, "height": 400, "rangesel": false, "syncZoom": false, "data": {"labels": ["index", "Trace 0:cpu_frequency:frequency", "Trace 0:sched_switch:next_pid"], "data": [[4.600000011123484e-05, NaN, 0.0], [0.0003069999997933337, NaN, 3346.0], [0.0008029999999052961, NaN, 3124.0], [0.0008569999999963329, NaN, 2950.0], [0.0008870000001479639, NaN, 3346.0], [0.0011709999998856802, NaN, 3259.0], [0.0012139999998908024, NaN, 0.0], [0.0012160000001131266, NaN, 0.0], [0.02190199999995457, NaN, 1959.0], [0.021920000000136497, NaN, 0.0], [0.029896999999891705, NaN, 1959.0], [0.029904999999871507, NaN, 0.0], [0.1612199999999575, NaN, 3259.0], [0.16130500000008396, NaN, 0.0], [0.16229599999996935, NaN, 3346.0], [0.16329300000006697, NaN, 3259.0], [0.16333799999983967, NaN, 0.0], [0.16398900000012873, NaN, 0.0], [0.16906900000003589, NaN, 3346.0], [0.16972799999985, NaN, 3259.0], [0.16974200000004203, NaN, 0.0], [0.16976400000021385, NaN, 0.0], [0.32821000000012646, NaN, 3259.0], [0.3282970000000205, NaN, 0.0], [0.3292999999998756, NaN, 3346.0], [0.33027099999981147, NaN, 3259.0], [0.3303139999998166, NaN, 0.0], [0.33096599999998944, NaN, 0.0], [0.3310519999999997, NaN, 2984.0], [0.33110500000020693, 1805.0, 2984.0], [0.3311060000000907, 1805.0, 2984.0], [0.3311065000000326, 1805.0, 2984.0], [0.3311069999999745, 1805.0, 2984.0], [0.3311229999999341, 1805.0, 3582.0], [0.3328040000001238, 1805.0, 3167.0], [0.33282099999996717, 1805.0, 3582.0], [0.33370800000011513, 1805.0, 3583.0], [0.3340400000001864, 1805.0, 29.0], [0.3340689999999995, 1805.0, 0.0], [0.33430200000020704, 1805.0, 3583.0], [0.3350900000000365, 1805.0, 0.0], [0.335095999999794, 1805.0, 3582.0], [0.33510400000022855, 1805.0, 1959.0], [0.33512500000006185, 1805.0, 0.0], [0.33549700000003213, 1805.0, 0.0], [0.3357219999998051, 1805.0, 3346.0], [0.3360059999999976, 1805.0, 0.0], [0.33609800000022005, 1805.0, 3259.0], [0.33611400000017966, 1805.0, 0.0], [0.34520999999995183, 1805.0, 2984.0], [0.34522400000014386, 1421.0, 2984.0], [0.34522500000002765, 1421.0, 2984.0], [0.34522599999991144, 1421.0, 2984.0], [0.3452269999999114, 1421.0, 2984.0], [0.34522900000001755, 1421.0, 0.0], [0.3498270000000048, 1421.0, 2984.0], [0.3498349999999846, 903.0, 2984.0], [0.34983549999992647, 903.0, 2984.0], [0.34983599999986836, 903.0, 2984.0], [0.34983699999986834, 903.0, 2984.0], [0.34983999999985826, 903.0, 0.0], [0.4949179999998705, 903.0, 3259.0], [0.495002999999997, 903.0, 0.0], [0.49598100000002887, 903.0, 3346.0], [0.49692000000004555, 903.0, 3259.0], [0.49696300000005067, 903.0, 0.0], [0.49774299999990035, 903.0, 0.0], [0.5013450000001285, 903.0, 3584.0], [0.5045690000001741, 903.0, 0.0], [0.5054690000001756, 903.0, 3585.0], [0.5056840000002012, 903.0, 3586.0], [0.5062219999999797, 903.0, 34.0], [0.5062659999998687, 903.0, 0.0], [0.5064550000001873, 903.0, 0.0], [0.5064790000001267, 903.0, 3275.0], [0.506492999999864, 903.0, 3584.0], [0.5064990000000762, 903.0, 0.0], [0.5069570000000567, 903.0, 0.0], [0.5071859999998196, 903.0, 3588.0], [0.5075879999999415, 903.0, 2984.0], [0.5076180000000932, 1805.0, 2984.0], [0.507618999999977, 1805.0, 2984.0], [0.5076194999999188, 1805.0, 2984.0], [0.5076199999998607, 1805.0, 2984.0], [0.5076309999999467, 1805.0, 3588.0], [0.5077900000001137, 1805.0, 3587.0], [0.5080809999999474, 1805.0, 3584.0], [0.5081009999998969, 1805.0, 0.0], [0.5082360000001245, 1805.0, 3584.0], [0.50826300000017, 1805.0, 0.0], [0.508310000000165, 1805.0, 34.0], [0.5083389999999781, 1805.0, 0.0], [0.5084109999997963, 1805.0, 3589.0], [0.5085829999998168, 1805.0, 3590.0], [0.5091059999999743, 1805.0, 3584.0], [0.5091459999998733, 1805.0, 34.0], [0.5091569999999592, 1805.0, 0.0], [0.5091689999999289, 1805.0, 0.0], [0.5093150000002424, 1805.0, 2984.0], [0. ...
