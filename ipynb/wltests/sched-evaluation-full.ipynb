# %% [markdown]
# # WLTests Results
# Analyses and visualises results generated by a wltest

# %%
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2017-11-30 17:41:32,131 INFO    : root         : Using LISA logging configuration:
# 2017-11-30 17:41:32,132 INFO    : root         :   /home/leoy/Work/tools/lisa-ml-20171106/logging.conf

# %%
import logging
from IPython.display import display

from wa_results_collector import WaResultsCollector
import pandas as pd

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Results analysis and metrics collection

# %%
collector = WaResultsCollector(
    
    # WLTests results folder:
    base_dir='/home/leoy/Work/tools/lisa-ml-20171106/results/wltest_boost_opt', # Base path of your results folders
    #wa_dirs='(substring_to_match)',   # Parse only folder matching this regexp
    
    # Results to collect:
    parse_traces=False,                # Enable trace parsing only to get more metrics
                                       # NOTE: results generation will take more times
    
    # Kernel tree used for the tests
    kernel_repo_path='/home/leoy/work3/hikey960/aosp_video/kernel/hikey-linaro'
)
# Out:
# 2017-11-30 18:38:48,757 INFO    : WaResultsCollector : Processing WA3 dirs matching [.*], rooted at /home/leoy/Work/tools/lisa-ml-20171106/results/wltest_boost_opt
# 2017-11-30 18:38:48,759 WARNING : WaResultsCollector : Trace parsing disabled

# %% [markdown]
# ## Collected metrics

# %%
df = collector.results_df
logging.info("Metrics available for plots and analysis:")
for metric in df.metric.unique().tolist():
    logging.info("   %s", metric)

df
# Out:
# 2017-11-30 18:39:04,716 INFO    : root         : Metrics available for plots and analysis:
# 2017-11-30 18:39:04,727 INFO    : root         :    jankbench_jank_frames
# 2017-11-30 18:39:04,728 INFO    : root         :    SYS_total_energy
# 2017-11-30 18:39:04,729 INFO    : root         :    VDD_total_energy
# 2017-11-30 18:39:04,730 INFO    : root         :    DCIN_total_energy
# 2017-11-30 18:39:04,731 INFO    : root         :    SYS_average_power
# 2017-11-30 18:39:04,732 INFO    : root         :    VDD_average_power
# 2017-11-30 18:39:04,734 INFO    : root         :    DCIN_average_power
# 2017-11-30 18:39:04,735 INFO    : root         :    frame_total_duration
#               id  iteration                 metric      tag              test  \
# 0    default-wk1          1  jankbench_jank_frames  iter_30         list_view
# 1    default-wk1          1       SYS_total_energy  iter_30         list_view
# 2    default-wk1          1       VDD_total_energy  iter_30         list_view
# 3    default-wk1          1      DCIN_total_energy  iter_30         list_view
# 4    default-wk1          1      SYS_average_power  iter_30         list_view
# 5    default-wk1          1      VDD_average_power  iter_30         list_view
# 6    default-wk1          1     DCIN_average_power  iter_30         list_view
# 7    default-wk2          1  jankbench_jank_frames  iter_30   image_list_view
# 8    default-wk2          1       SYS_total_energy  iter_30   image_list_view
# 9    default-wk2          1       VDD_total_energy  iter_30   image_list_view
# 10   default-wk2          1      DCIN_total_energy  iter_30   image_list_view
# 11   default-wk2          1      SYS_average_power  iter_30   image_list_view
# 12   default-wk2          1      VDD_average_power  iter_30   image_list_view
# 13   default-wk2          1     DCIN_average_power  iter_30   image_list_view
# 14   default-wk3          1  jankbench_jank_frames  iter_30       shadow_grid
# 15   default-wk3          1       SYS_total_energy  iter_30       shadow_grid
# 16   default-wk3          1       VDD_total_energy  iter_30       shadow_grid
# 17   default-wk3          1      DCIN_total_energy  iter_30       shadow_grid
# 18   default-wk3          1      SYS_average_power  iter_30       shadow_grid
# 19   default-wk3          1      VDD_average_power  iter_30       shadow_grid
# 20   default-wk3          1     DCIN_average_power  iter_30       shadow_grid
# 21   default-wk4          1  jankbench_jank_frames  iter_30  low_hitrate_text
# 22   default-wk4          1       SYS_total_energy  iter_30  low_hitrate_text
# 23   default-wk4          1       VDD_total_energy  iter_30  low_hitrate_text
# 24   default-wk4          1      DCIN_total_energy  iter_30  low_hitrate_text
# 25   default-wk4          1      SYS_average_power  iter_30  low_hitrate_text
# 26   default-wk4          1      VDD_average_power  iter_30  low_hitrate_text
# 27   default-wk4          1     DCIN_average_power  iter_30  low_hitrate_text
# 28   default-wk5          1  jankbench_jank_frames  iter_30         edit_text
# 29   default-wk5          1       SYS_total_energy  iter_30         edit_text
# ..           ...        ...                    ...      ...               ...
# 115  default-wk5         10   frame_total_duration  iter_30         edit_text
# 116  default-wk5         10   frame_total_duration  iter_30         edit_text
# 117  default-wk5         10   frame_total_duration  iter_30         edit_text
# 118  default-wk5         10   frame_total_duration  iter_30         edit_text
# 119  default-wk5         10   frame_total_duration  iter_30         edit_text
# 120  default-wk5         10   frame_total_duration  iter_30         edit_text
# 121  default-wk5         10   frame_total_duration  iter_30         edit_text
# 122  default-wk5         10   frame_total_duration  iter_30         edit_text
# 123  default-wk5         10   frame_total_duration  iter_30         edit_text
# 124  default-wk5         10   frame_total_duration  iter_30         edit_text
# 125  default-wk5         10   frame_total_duration  iter_30         edit_text
# 126  default-wk5         10   frame_total_duration  iter_30         edit_text
# 127  default-wk5         10   frame_total_duration  iter_30         edit_text
# 128  default-wk5         10   frame_total_duration  iter_30         edit_text
# 129  default-wk5         10   frame_total_duration  iter_30         edit_text
# 130  default-wk5         10   frame_total_duration  iter_30         edit_text
# 131  default-wk5         10   frame_total_duration  iter_30         edit_text
# 132  default-wk5         10   frame_total_duration  iter_30         edit_text
# 133  default-wk5         10   frame_total_duration  iter_30         edit_text
# 134  default-wk5         10   frame_total_duration  iter_30         edit_text
# 135  default-wk5         10   frame_total_duration  iter_30         edit_text
# 136  default-wk5         10   frame_total_duration  iter_30         edit_text
# 137  default-wk5         10   frame_total_duration  iter_30         edit_text
# 138  default-wk5         10   frame_total_duration  iter_30         edit_text
# 139  default-wk5         10   frame_total_duration  iter_30         edit_text
# 140  default-wk5         10   frame_total_duration  iter_30         edit_text
# 141  default-wk5         10   frame_total_duration  iter_30         edit_text
# 142  default-wk5         10   frame_total_duration  iter_30         edit_text
# 143  default-wk5         10   frame_total_duration  iter_30         edit_text
# 144  default-wk5         10   frame_total_duration  iter_30         edit_text
#
#       units       value   workload  \
# 0       NaN  863.000000  jankbench
# 1    joules    0.009202  jankbench
# 2    joules  208.633569  jankbench
# 3    joules    0.012675  jankbench
# 4     watts    0.000253  jankbench
# 5     watts    5.744652  jankbench
# 6     watts    0.000349  jankbench
# 7       NaN  910.000000  jankbench
# 8    joules    0.009106  jankbench
# 9    joules  207.885541  jankbench
# 10   joules    0.012523  jankbench
# 11    watts    0.000254  jankbench
# 12    watts    5.764531  jankbench
# 13    watts    0.000349  jankbench
# 14      NaN  874.000000  jankbench
# 15   joules    0.009030  jankbench
# 16   joules  211.100481  jankbench
# 17   joules    0.012452  jankbench
# 18    watts    0.000253  jankbench
# 19    watts    5.910504  jankbench
# 20    watts    0.000349  jankbench
# 21      NaN  721.000000  jankbench
# 22   joules    0.008958  jankbench
# 23   joules  230.933333  jankbench
# 24   joules    0.012419  jankbench
# 25    watts    0.000252  jankbench
# 26    watts    6.504632  jankbench
# 27    watts    0.000350  jankbench
# 28      NaN    5.000000  jankbench
# 29   joules    0.002307  jankbench
# ..      ...         ...        ...
# 115      ms    4.832735  jankbench
# 116      ms    7.947672  jankbench
# 117      ms    3.715506  jankbench
# 118      ms    4.209422  jankbench
# 119      ms    4.319467  jankbench
# 120      ms    4.201868  jankbench
# 121      ms    3.706356  jankbench
# 122      ms    4.729202  jankbench
# 123      ms    4.235512  jankbench
# 124      ms    4.428565  jankbench
# 125      ms    3.944006  jankbench
# 126      ms    3.490144  jankbench
# 127      ms    4.475653  jankbench
# 128      ms    4.291607  jankbench
# 129      ms    4.338713  jankbench
# 130      ms    4.300444  jankbench
# 131      ms    3.931868  jankbench
# 132      ms    3.686184  jankbench
# 133      ms    4.283323  jankbench
# 134      ms    4.351661  jankbench
# 135      ms    3.832971  jankbench
# 136      ms    4.147810  jankbench
# 137      ms    4.982287  jankbench
# 138      ms    4.546621  jankbench
# 139      ms    4.974578  jankbench
# 140      ms    5.923865  jankbench
# 141      ms    6.898152  jankbench
# 142      ms   24.151557  jankbench
# 143      ms    8.776283  jankbench
# 144      ms    4.953637  jankbench
#
#                                               _job_dir kernel_sha1  \
# 0    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 1    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 2    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 3    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 4    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 5    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 6    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 7    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 8    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 9    /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 10   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 11   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 12   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 13   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 14   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 15   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 16   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 17   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 18   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 19   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 20   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 21   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 22   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 23   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 24   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 25   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 26   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 27   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 28   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# 29   /home/leoy/Work/tools/lisa-ml-20171106/results...     4c971ab
# ..                                                 ...         ...
# 115  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 116  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 117  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 118  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 119  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 120  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 121  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 122  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 123  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 124  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 125  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 126  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 127  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 128  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 129  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 130  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 131  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 132  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 133  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 134  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 135  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 136  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 137  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 138  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 139  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 140  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 141  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 142  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 143  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
# 144  /home/leoy/Work/tools/lisa-ml-20171106/results...     c1d9abd
#
#              kernel
# 0      powerhal-opt
# 1      powerhal-opt
# 2      powerhal-opt
# 3      powerhal-opt
# 4      powerhal-opt
# 5      powerhal-opt
# 6      powerhal-opt
# 7      powerhal-opt
# 8      powerhal-opt
# 9      powerhal-opt
# 10     powerhal-opt
# 11     powerhal-opt
# 12     powerhal-opt
# 13     powerhal-opt
# 14     powerhal-opt
# 15     powerhal-opt
# 16     powerhal-opt
# 17     powerhal-opt
# 18     powerhal-opt
# 19     powerhal-opt
# 20     powerhal-opt
# 21     powerhal-opt
# 22     powerhal-opt
# 23     powerhal-opt
# 24     powerhal-opt
# 25     powerhal-opt
# 26     powerhal-opt
# 27     powerhal-opt
# 28     powerhal-opt
# 29     powerhal-opt
# ..              ...
# 115  1109-util-zero
# 116  1109-util-zero
# 117  1109-util-zero
# 118  1109-util-zero
# 119  1109-util-zero
# 120  1109-util-zero
# 121  1109-util-zero
# 122  1109-util-zero
# 123  1109-util-zero
# 124  1109-util-zero
# 125  1109-util-zero
# 126  1109-util-zero
# 127  1109-util-zero
# 128  1109-util-zero
# 129  1109-util-zero
# 130  1109-util-zero
# 131  1109-util-zero
# 132  1109-util-zero
# 133  1109-util-zero
# 134  1109-util-zero
# 135  1109-util-zero
# 136  1109-util-zero
# 137  1109-util-zero
# 138  1109-util-zero
# 139  1109-util-zero
# 140  1109-util-zero
# 141  1109-util-zero
# 142  1109-util-zero
# 143  1109-util-zero
# 144  1109-util-zero
#
# [110736 rows x 11 columns]

# %% [markdown]
# # Jankbench

# %% [markdown]
# ## Total Frame Duration

# %%
for test in collector.tests(workload='jankbench'):
    logging.info("Results for: %s", test)
    collector.report(workload='jankbench', metric='frame_total_duration',
                     test=test, sort_on='99%', ascending=True)
# Out:
# 2017-11-30 18:44:41,440 INFO    : root         : Results for: list_view
#                                        frame_total_duration             \
#                                                       count       mean
# test            tag     kernel
# list_view       iter_30 1109-util-zero              13663.0  38.242040
#                         powerhal-opt                13138.0  43.035221
# image_list_view iter_30 1109-util-zero              13660.0  39.800309
#                         powerhal-opt                13165.0  43.509071
#
#                                                                         \
#                                               std       min        50%
# test            tag     kernel
# list_view       iter_30 1109-util-zero  25.793058  1.495823  36.473707
#                         powerhal-opt    24.328311  2.693120  39.500305
# image_list_view iter_30 1109-util-zero  24.897075  1.687542  36.969385
#                         powerhal-opt    23.934932  2.409150  39.340221
#
#                                                                           \
#                                               75%        95%         99%
# test            tag     kernel
# list_view       iter_30 1109-util-zero  48.974127  90.600607   99.987744
#                         powerhal-opt    56.367268  92.278022  100.147364
# image_list_view iter_30 1109-util-zero  50.355507  90.704550  100.266184
#                         powerhal-opt    56.328783  92.448644  100.282313
#
#
#                                                max
# test            tag     kernel
# list_view       iter_30 1109-util-zero  389.959612
#                         powerhal-opt    164.686285
# image_list_view iter_30 1109-util-zero  132.719760
#                         powerhal-opt    156.339749
# 2017-11-30 18:44:42,558 INFO    : root         : Results for: image_list_view
#                                        frame_total_duration             \
#                                                       count       mean
# test            tag     kernel
# image_list_view iter_30 1109-util-zero              13660.0  39.800309
#                         powerhal-opt                13165.0  43.509071
#
#                                                                         \
#                                               std       min        50%
# test            tag     kernel
# image_list_view iter_30 1109-util-zero  24.897075  1.687542  36.969385
#                         powerhal-opt    23.934932  2.409150  39.340221
#
#                                                                           \
#                                               75%        95%         99%
# test            tag     kernel
# image_list_view iter_30 1109-util-zero  50.355507  90.704550  100.266184
#                         powerhal-opt    56.328783  92.448644  100.282313
#
#
#                                                max
# test            tag     kernel
# image_list_view iter_30 1109-util-zero  132.719760
#                         powerhal-opt    156.339749
# 2017-11-30 18:44:43,507 INFO    : root         : Results for: shadow_grid
#                                    frame_total_duration                        \
#                                                   count       mean        std
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt                12994.0  38.683288  23.154085
#                     1109-util-zero              13057.0  36.361226  25.114535
#
#                                                                                \
#                                          min        50%        75%        95%
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt    3.319076  36.552136  48.404095  85.242227
#                     1109-util-zero  2.449498  33.586813  47.276772  88.948574
#
#
#                                            99%         max
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt     98.826939  272.137625
#                     1109-util-zero  100.250656  265.959141
# 2017-11-30 18:44:44,327 INFO    : root         : Results for: low_hitrate_text
#                                         frame_total_duration             \
#                                                        count       mean
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt                13900.0  33.781817
#                          1109-util-zero              13618.0  31.717737
#
#                                                                          \
#                                                std       min        50%
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt    16.805256  5.184505  32.271286
#                          1109-util-zero  21.782040  3.217962  29.678207
#
#                                                                           \
#                                                75%        95%        99%
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt    42.952638  65.226321  86.801652
#                          1109-util-zero  42.294170  79.493209  97.515279
#
#
#                                                 max
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt    173.146879
#                          1109-util-zero  144.108244
# 2017-11-30 18:44:45,276 INFO    : root         : Results for: edit_text
#                                  frame_total_duration                        \
#                                                 count       mean        std
# test      tag     kernel
# edit_text iter_30 1109-util-zero               1426.0  13.966616  13.502642
#                   powerhal-opt                 1427.0  11.310150  11.678339
#
#                                                                             \
#                                        min       50%        75%        95%
# test      tag     kernel
# edit_text iter_30 1109-util-zero  2.994554  8.795915  17.843820  44.942955
#                   powerhal-opt    3.219468  6.896965  12.357693  28.785908
#
#
#                                         99%         max
# test      tag     kernel
# edit_text iter_30 1109-util-zero  58.917044  101.831404
#                   powerhal-opt    65.145260  111.210875

# %% [markdown]
# ## Energy

# %%
for test in collector.tests(workload='jankbench'):
    logging.info("Results for: %s", test)
    collector.report(workload='jankbench', metric='VDD_average_power',
                     test=test, sort_on='99%', ascending=True)
# Out:
# 2017-11-30 18:51:08,395 INFO    : root         : Results for: list_view
#                                        VDD_average_power                      \
#                                                    count      mean       std
# test            tag     kernel
# list_view       iter_30 powerhal-opt                10.0  5.875298  0.082454
# image_list_view iter_30 powerhal-opt                10.0  6.005977  0.115335
# list_view       iter_30 1109-util-zero              10.0  6.650697  0.227547
# image_list_view iter_30 1109-util-zero              10.0  6.776095  0.169664
#
#                                                                       \
#                                              min       50%       75%
# test            tag     kernel
# list_view       iter_30 powerhal-opt    5.744652  5.865240  5.937440
# image_list_view iter_30 powerhal-opt    5.764531  6.029834  6.048650
# list_view       iter_30 1109-util-zero  6.149760  6.686675  6.755363
# image_list_view iter_30 1109-util-zero  6.388511  6.827591  6.846823
#
#
#                                              95%       99%       max
# test            tag     kernel
# list_view       iter_30 powerhal-opt    5.988652  6.002178  6.005559
# image_list_view iter_30 powerhal-opt    6.149248  6.191650  6.202250
# list_view       iter_30 1109-util-zero  6.907979  6.922758  6.926453
# image_list_view iter_30 1109-util-zero  6.956060  6.956067  6.956069
# 2017-11-30 18:51:09,358 INFO    : root         : Results for: image_list_view
#                                        VDD_average_power                      \
#                                                    count      mean       std
# test            tag     kernel
# image_list_view iter_30 powerhal-opt                10.0  6.005977  0.115335
#                         1109-util-zero              10.0  6.776095  0.169664
#
#                                                                       \
#                                              min       50%       75%
# test            tag     kernel
# image_list_view iter_30 powerhal-opt    5.764531  6.029834  6.048650
#                         1109-util-zero  6.388511  6.827591  6.846823
#
#
#                                              95%       99%       max
# test            tag     kernel
# image_list_view iter_30 powerhal-opt    6.149248  6.191650  6.202250
#                         1109-util-zero  6.956060  6.956067  6.956069
# 2017-11-30 18:51:10,275 INFO    : root         : Results for: shadow_grid
#                                    VDD_average_power                      \
#                                                count      mean       std
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt                 9.0  6.127775  0.118649
#                     1109-util-zero               9.0  6.976268  0.128322
#
#                                                                             \
#                                          min       50%       75%       95%
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt    5.910504  6.124597  6.240309  6.254278
#                     1109-util-zero  6.688714  6.980463  7.065806  7.108188
#
#
#                                          99%       max
# test        tag     kernel
# shadow_grid iter_30 powerhal-opt    6.260491  6.262044
#                     1109-util-zero  7.112962  7.114156
# 2017-11-30 18:51:11,165 INFO    : root         : Results for: low_hitrate_text
#                                         VDD_average_power                      \
#                                                     count      mean       std
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt                10.0  6.570941  0.053039
#                          1109-util-zero              10.0  7.345437  0.150906
#
#                                                                        \
#                                               min       50%       75%
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt    6.504632  6.564026  6.609955
#                          1109-util-zero  7.006351  7.373724  7.408510
#
#
#                                               95%       99%       max
# test             tag     kernel
# low_hitrate_text iter_30 powerhal-opt    6.647480  6.660123  6.663283
#                          1109-util-zero  7.521157  7.535830  7.539498
# 2017-11-30 18:51:12,013 INFO    : root         : Results for: edit_text
#                                  VDD_average_power                      \
#                                              count      mean       std
# test      tag     kernel
# edit_text iter_30 powerhal-opt                10.0  7.486441  0.142614
#                   1109-util-zero              10.0  7.778122  0.157251
#
#                                                                           \
#                                        min       50%       75%       95%
# test      tag     kernel
# edit_text iter_30 powerhal-opt    7.235649  7.509617  7.615111  7.629451
#                   1109-util-zero  7.595217  7.793453  7.868538  8.008875
#
#
#                                        99%       max
# test      tag     kernel
# edit_text iter_30 powerhal-opt    7.633653  7.634704
#                   1109-util-zero  8.063485  8.077138

# %% [markdown]
# ## Frames Duration CDF

# %%
for test in collector.tests(workload='jankbench'):
    logging.info("Results for: %s", test)
    collector.plot_cdf(workload='jankbench', metric='frame_total_duration', test=test, threshold=16)
# Out:
# 2017-11-30 18:45:54,982 INFO    : root         : Results for: list_view
# 2017-11-30 18:45:56,097 INFO    : root         : Results for: image_list_view
# 2017-11-30 18:45:57,006 INFO    : root         : Results for: shadow_grid
# 2017-11-30 18:45:57,865 INFO    : root         : Results for: low_hitrate_text
# 2017-11-30 18:45:58,600 INFO    : root         : Results for: edit_text

# %% [markdown]
# # Exoplayer

# %% [markdown]
# ## Dropper Frames

# %%
for test in collector.tests(workload='exoplayer'):
    logging.info("Results for: %s", test)
    collector.report(workload='exoplayer', metric='exoplayer_dropped_frames',
                     test=test, sort_on='99%', ascending=True)

# %% [markdown]
# ## Energy

# %%
for test in collector.tests(workload='exoplayer'):
    logging.info("Results for: %s", test)
    collector.report(workload='exoplayer', metric='device_total_energy',
                     test=test, sort_on='99%', ascending=True)

# %% [markdown]
# # Homescreen

# %%
for test in collector.tests(workload='homescreen'):
    logging.info("Results for: %s", test)
    collector.report(workload='homescreen', metric='device_total_energy',
                     test=test, sort_on='99%', ascending=True)

# %% [markdown]
# # Geekbench

# %% [markdown]
# ## Overall scores

# %%
for metric in [ 'Single-Core_score', 'Multi-Core_score']:
    collector.report(workload='geekbench', metric=metric,
                     sort_on='99%', ascending=False)

# %% [markdown]
# ## Detailed scores

# %%
# Get Geekbench scores
df = collector.results_df
gb_scores_db = df[df.test == 'geekbench']

# Group scores
grouped_df = gb_scores_db.groupby(['test', 'tag', 'kernel', 'metric'])

# Get stats for grouped scores
stats_df = pd.DataFrame(grouped_df.describe(percentiles=[.95, .99]))
stats_df = stats_df.reset_index().rename(columns={'level_4': 'stats'})

# %% [markdown]
# ### Single Core Scores

# %%
single_score_df = stats_df[stats_df.metric.str.match('Single.*')][['metric', 'kernel', 'stats', 'value']]
single_score_df['metric'] = single_score_df.metric.apply(lambda s : s.replace('Single-Core_', '').replace('_score', ''))
single_score_df = single_score_df.set_index(['metric', 'kernel', 'stats']).unstack()
logging.info("Detailed SINGLE core scores:")
single_score_df

# %% [markdown]
# ### Multi Core Scores

# %%
multi_score_df = stats_df[stats_df.metric.str.match('Multi.*')][['metric', 'kernel', 'stats', 'value']]
multi_score_df['metric'] = multi_score_df.metric.apply(lambda s : s.replace('Multi-Core_', '').replace('_score', ''))
multi_score_df = multi_score_df.set_index(['metric', 'kernel', 'stats']).unstack()
logging.info("Detailed SINGLE core scores:")
multi_score_df

# %% [markdown]
# # PCMark Scores

# %% [markdown]
# ## Overall Scores

# %%
pm_scores = [m for m in pm_df.metric.unique().tolist() if m.startswith('pcmark_')]
for metric in pm_scores:
    collector.report(workload='pcmark', metric=metric,
                     sort_on='99%', ascending=False)

# %% [markdown]
# ## Detailed Scores

# %%
# Get Geekbench scores
df = collector.results_df
pm_scores_db = df[df.workload == 'pcmark']

# Group scores
grouped_df = pm_scores_db.groupby(['test', 'tag', 'kernel', 'metric'])

# Get stats for grouped scores
stats_df = pd.DataFrame(grouped_df.describe(percentiles=[.95, .99]))
stats_df = stats_df.reset_index().rename(columns={'level_4': 'stats'})

# %%
pm_score_df = stats_df[stats_df.metric.str.match('pcmark_.*')][['metric', 'kernel', 'stats', 'value']]
pm_score_df['metric'] = pm_score_df.metric.apply(lambda s : s.replace('pcmark_', ''))
pm_score_df = pm_score_df.set_index(['metric', 'kernel', 'stats']).unstack()
logging.info("Detailed scores:")
pm_score_df

# %% [markdown]
# # Generic comparison plots
# `plot_comparisons` can be used to automatically discover metrics that changed between different kernel versions or tags.

# %%
logging.info("Here is the list of kernels available:")
logging.info("  %s", ', '.join(df['kernel'].unique().tolist() ))
# Out:
# 2017-11-30 18:26:30,859 INFO    : root         : Here is the list of kernels available:
# 2017-11-30 18:26:30,865 INFO    : root         :

# %%
# Select the baseline kernels for comparisions:
# by deafult we use the first available:
kernel_baseline = df['kernel'].iloc[0]
# Or defined here below one of the above reported kernels as baseline for comparisions
# kernel_baseline = "PutHereYourKernelName"

logging.info("Comparing against baseline kernel: %s", kernel_baseline)
collector.plot_comparisons(base_id=kernel_baseline, by='kernel')
# Out:
# 2017-11-30 18:26:31,116 INFO    : root         : Comparing against baseline kernel:
# 2017-11-30 18:26:31,290 ERROR   : WaResultsCollector : No comparisons by kernel found
# 2017-11-30 18:26:31,294 WARNING : WaResultsCollector : There is only one kernel in the results
