# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

df = pd.read_csv ('/home/leoy/Downloads/ftrace-ramoops-0.warmreset-20201028.txt', sep=' ')

# %%
df.groupby('SyS_write').count()
# Out:
#                                       1  ffff000008243a38  Unnamed: 2  \
# SyS_write
# SyS_write                           385               385           0
# __acct_update_integrals              12                12           0
# __calc_delta                         90                90           0
# __compute_runnable_contrib.part.12   19                19           0
# __do_softirq                          8                 8           0
# __enqueue_entity                      1                 1           0
# __fdget_pos                         386               386           0
# __fget_light                        386               386           0
# __fsnotify_parent                   384               384           0
# __handle_domain_irq                   8                 8           0
# __hrtimer_get_next_event             12                12           0
# __hrtimer_run_queues                 12                12           0
# ...
